# %% [markdown]
# # 01 — Data Loading
#
# ## Purpose
# Plan the controlled loading of approved candidate, job, and application datasets.
#
# ## Planned Inputs
# - Candidate records
# - Job records
# - Application records
#
# ## Planned Checks
# - Confirm source provenance, version, and permitted use.
# - Confirm file format and expected schema availability.
# - Record row counts and field names without exposing personal data.
#
# ## Privacy Controls
# Use approved, access-controlled data only. Do not commit real candidate information to this notebook or the repository.

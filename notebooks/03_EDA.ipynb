# %% [markdown]
# # 03 — Exploratory Data Analysis
#
# ## Purpose
# Plan descriptive analysis of dataset composition, quality, and representation before any model development.
#
# ## Planned Analysis Sections
# - Dataset overview and entity-level record counts
# - Missing values and duplicate-record analysis
# - Skill frequency and normalization review
# - Experience and education distributions
# - Data quality issues and relationship validation
# - Bias, coverage, and representativeness considerations
#
# ## Expected Outputs
# Summarize approved findings in `reports/EDA_Report.md`. Results must be aggregated, privacy-preserving, and accompanied by data-quality limitations.
#
# ## Guardrails
# This notebook is for descriptive planning only. Do not train models, make candidate-level decisions, or publish sensitive data.
